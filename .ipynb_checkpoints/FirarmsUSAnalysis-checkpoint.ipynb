# %% [markdown]
# # Project: Firearms USA
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# ## Helper Functions

# %%
# Dropping columns with more than number_NaNs NaN values
def DropColumns(df, number_nans):
    '''
    Desc: Function that takes two values to return Dataframe without NaN values
    
    Input: df: Pandas Dataframe that has number of NaN values
           number_nans: Integer with the number of NaN values decided to remove the whole column (as it will not be informative)
           
    Output: df_no_nans: Pandas Dataframe with dropped columns that contain higher number of NaN values than desired
    '''
    columns_to_drop = []
    for column in df.columns:
        if (df[column].isna().sum()>number_nans) == True:
            columns_to_drop.append(column)
    df_no_nans = df.drop(columns=columns_to_drop)
    return df_no_nans

# Brings last column in df to be the first
def BeginWithLast(df):
    '''
    Desc: Function that brings the column at the end to be at the beginning
    
    Input: df: Pandas Dataframe
    
    Output: df: Pandas Dataframe
    '''
    cols = list(df.columns)
    cols = [cols[-1]] + cols[:-1]
    df = df[cols]
    return df

# Gets the length of years mentioned in the column
def getLengthYearValues(x):
    '''
    Desc: Functions that gets the number of years had been mentioned in a column
    
    Input: x: String values specified in a column
    
    Output: n: Integer number of year values found in string'''
    n = len(list(set(re.findall(r'[0-9]{4}', x))))
    return n

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
# ### General Properties

# %%
gun_df = pd.read_csv('FirearmsUSA2020.csv')
census_df = pd.read_csv('U.S. Census Data.csv')

# %%
gun_df.head()
# Out:
#      month       state   permit  permit_recheck  handgun  long_gun   other  \
# 0  2020-07     Alabama  48126.0           682.0  34909.0   17250.0  2498.0
# 1  2020-07      Alaska     69.0           152.0   4949.0    3779.0   435.0
# 2  2020-07     Arizona   9402.0           900.0  31040.0   12361.0  2411.0
# 3  2020-07    Arkansas   4292.0           847.0  12391.0    7322.0   738.0
# 4  2020-07  California  35097.0             0.0  67672.0   38618.0  7530.0
#
#    multiple  admin  prepawn_handgun  ...  returned_other  rentals_handgun  \
# 0      1170    0.0             33.0  ...             0.0              0.0
# 1       283    0.0              0.0  ...             0.0              0.0
# 2      2866    0.0              7.0  ...             1.0              0.0
# 3       432    3.0             12.0  ...             0.0              0.0
# 4         0    0.0              0.0  ...             0.0              0.0
#
#    rentals_long_gun  private_sale_handgun  private_sale_long_gun  \
# 0               0.0                  43.0                   23.0
# 1               0.0                  14.0                    6.0
# 2               0.0                  23.0                   10.0
# 3               0.0                  19.0                   16.0
# 4               0.0                   0.0                    0.0
#
#    private_sale_other  return_to_seller_handgun  return_to_seller_long_gun  \
# 0                10.0                       1.0                        2.0
# 1                 2.0                       0.0                        0.0
# 2                 4.0                       0.0                        0.0
# 3                 0.0                       1.0                        0.0
# 4                 0.0                       0.0                        0.0
#
#    return_to_seller_other  totals
# 0                     0.0  107490
# 1                     0.0   10108
# 2                     0.0   60330
# 3                     0.0   27647
# 4                     0.0  149685
#
# [5 rows x 27 columns]

# %%
print('Number of rows is ' + str(gun_df.shape[0]) + ', while the number of columns is ' + str(gun_df.shape[1]) + '.')
# Out:
# Number of rows is 14355, while the number of columns is 27.

# %%
# dataset's columns
gun_df.columns
# Out:
# Index(['month', 'state', 'permit', 'permit_recheck', 'handgun', 'long_gun',
#        'other', 'multiple', 'admin', 'prepawn_handgun', 'prepawn_long_gun',
#        'prepawn_other', 'redemption_handgun', 'redemption_long_gun',
#        'redemption_other', 'returned_handgun', 'returned_long_gun',
#        'returned_other', 'rentals_handgun', 'rentals_long_gun',
#        'private_sale_handgun', 'private_sale_long_gun', 'private_sale_other',
#        'return_to_seller_handgun', 'return_to_seller_long_gun',
#        'return_to_seller_other', 'totals'],
#       dtype='object')

# %%
# Number of NaN values in each column
gun_df.isna().sum()
# Out:
# month                            0
# state                            0
# permit                          24
# permit_recheck               11385
# handgun                         20
# long_gun                        19
# other                         6985
# multiple                         0
# admin                           23
# prepawn_handgun               1943
# prepawn_long_gun              1945
# prepawn_other                 7370
# redemption_handgun            1940
# redemption_long_gun           1941
# redemption_other              7370
# returned_handgun             10285
# returned_long_gun            10340
# returned_other               10670
# rentals_handgun              11495
# rentals_long_gun             11660
# private_sale_handgun          9735
# private_sale_long_gun         9735
# private_sale_other            9735
# return_to_seller_handgun     10010
# return_to_seller_long_gun     9735
# return_to_seller_other       10230
# totals                           0
# dtype: int64

# %% [markdown]
# There are around 14 thousands rows in this dataset, there are many columns that have even more than 10 thousands NaNs. Columns with thousands NaNs don't carry any useful information. They will be dropped later on in this notebook.

# %%
gun_df.isna().sum()>1000
# Out:
# month                        False
# state                        False
# permit                       False
# permit_recheck                True
# handgun                      False
# long_gun                     False
# other                         True
# multiple                     False
# admin                        False
# prepawn_handgun               True
# prepawn_long_gun              True
# prepawn_other                 True
# redemption_handgun            True
# redemption_long_gun           True
# redemption_other              True
# returned_handgun              True
# returned_long_gun             True
# returned_other                True
# rentals_handgun               True
# rentals_long_gun              True
# private_sale_handgun          True
# private_sale_long_gun         True
# private_sale_other            True
# return_to_seller_handgun      True
# return_to_seller_long_gun     True
# return_to_seller_other        True
# totals                       False
# dtype: bool

# %%
gun_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14355 entries, 0 to 14354
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      14355 non-null  object
#  1   state                      14355 non-null  object
#  2   permit                     14331 non-null  float64
#  3   permit_recheck             2970 non-null   float64
#  4   handgun                    14335 non-null  float64
#  5   long_gun                   14336 non-null  float64
#  6   other                      7370 non-null   float64
#  7   multiple                   14355 non-null  int64
#  8   admin                      14332 non-null  float64
#  9   prepawn_handgun            12412 non-null  float64
#  10  prepawn_long_gun           12410 non-null  float64
#  11  prepawn_other              6985 non-null   float64
#  12  redemption_handgun         12415 non-null  float64
#  13  redemption_long_gun        12414 non-null  float64
#  14  redemption_other           6985 non-null   float64
#  15  returned_handgun           4070 non-null   float64
#  16  returned_long_gun          4015 non-null   float64
#  17  returned_other             3685 non-null   float64
#  18  rentals_handgun            2860 non-null   float64
#  19  rentals_long_gun           2695 non-null   float64
#  20  private_sale_handgun       4620 non-null   float64
#  21  private_sale_long_gun      4620 non-null   float64
#  22  private_sale_other         4620 non-null   float64
#  23  return_to_seller_handgun   4345 non-null   float64
#  24  return_to_seller_long_gun  4620 non-null   float64
#  25  return_to_seller_other     4125 non-null   float64
#  26  totals                     14355 non-null  int64
# dtypes: float64(23), int64(2), object(2)
# memory usage: 3.0+ MB

# %%
# Checking what the 'totals' attribute represents
no_na_gun_df = gun_df.dropna()
print('Is the summation of all the values in each row except for the "totals" equal to the "totals" fields?\n', 
      not (False in (no_na_gun_df.drop(columns=['month', 'state', 'totals']).sum(axis=1)\
            .apply(lambda x: int(x)) == no_na_gun_df['totals']).values))
# Out:
# Is the summation of all the values in each row except for the "totals" equal to the "totals" fields?
#  True

# %% [markdown]
# The left hand side of the '==' is the summation of all the fields (except 'totals') of each row, the right hand side of it is the values of the 'totals' attribute.

# %%
census_df.head()
# Out:
#                                                 Fact Fact Note    Alabama  \
# 0       Population estimates, July 1, 2016,  (V2016)       NaN  4,863,300
# 1  Population estimates base, April 1, 2010,  (V2...       NaN  4,780,131
# 2  Population, percent change - April 1, 2010 (es...       NaN      1.70%
# 3                  Population, Census, April 1, 2010       NaN  4,779,736
# 4  Persons under 5 years, percent, July 1, 2016, ...       NaN      6.00%
#
#     Alaska    Arizona   Arkansas  California   Colorado Connecticut Delaware  \
# 0  741,894  6,931,071  2,988,248  39,250,017  5,540,545   3,576,452  952,065
# 1  710,249  6,392,301  2,916,025  37,254,522  5,029,324   3,574,114  897,936
# 2    4.50%      8.40%      2.50%       5.40%     10.20%       0.10%    6.00%
# 3  710,231  6,392,017  2,915,918  37,253,956  5,029,196   3,574,097  897,934
# 4    7.30%      6.30%      6.40%       6.30%      6.10%       5.20%    5.80%
#
#    ... South Dakota Tennessee       Texas       Utah  Vermont   Virginia  \
# 0  ...       865454   6651194  27,862,596  3,051,217  624,594  8,411,808
# 1  ...       814195   6346298  25,146,100  2,763,888  625,741  8,001,041
# 2  ...        0.063     0.048      10.80%     10.40%   -0.20%      5.10%
# 3  ...       814180   6346105  25,145,561  2,763,885  625,741  8,001,024
# 4  ...        0.071     0.061       7.20%      8.30%    4.90%      6.10%
#
#   Washington West Virginia  Wisconsin  Wyoming
# 0  7,288,000     1,831,102  5,778,708  585,501
# 1  6,724,545     1,853,011  5,687,289  563,767
# 2      8.40%        -1.20%      1.60%    3.90%
# 3  6,724,540     1,852,994  5,686,986  563,626
# 4      6.20%         5.50%      5.80%    6.50%
#
# [5 rows x 52 columns]

# %%
print('Number of rows is ' + str(census_df.shape[0]) + ', while the number of columns is ' + str(census_df.shape[1]) + '.')
# Out:
# Number of rows is 85, while the number of columns is 52.

# %%
census_df.isna().sum()
# Out:
# Fact               5
# Fact Note         57
# Alabama           20
# Alaska            20
# Arizona           20
# Arkansas          20
# California        20
# Colorado          20
# Connecticut       20
# Delaware          20
# Florida           20
# Georgia           20
# Hawaii            20
# Idaho             20
# Illinois          20
# Indiana           20
# Iowa              20
# Kansas            20
# Kentucky          20
# Louisiana         20
# Maine             20
# Maryland          20
# Massachusetts     20
# Michigan          20
# Minnesota         20
# Mississippi       20
# Missouri          20
# Montana           20
# Nebraska          20
# Nevada            20
# New Hampshire     20
# New Jersey        20
# New Mexico        20
# New York          20
# North Carolina    20
# North Dakota      20
# Ohio              20
# Oklahoma          20
# Oregon            20
# Pennsylvania      20
# Rhode Island      20
# South Carolina    20
# South Dakota      20
# Tennessee         20
# Texas             20
# Utah              20
# Vermont           20
# Virginia          20
# Washington        20
# West Virginia     20
# Wisconsin         20
# Wyoming           20
# dtype: int64

# %% [markdown]
# Probably, the 20 NaNs in all the states are from the same rows.

# %%
# Checking if the 20 NaNs in all the states are from the same rows
print('Number of rows in this dataset is ' + str(len(census_df)) + '.')
census_df.drop(columns=['Fact', 'Fact Note']).dropna()
# Out:
# Number of rows in this dataset is 85.
#       Alabama      Alaska     Arizona   Arkansas  California    Colorado  \
# 0   4,863,300     741,894   6,931,071  2,988,248  39,250,017   5,540,545
# 1   4,780,131     710,249   6,392,301  2,916,025  37,254,522   5,029,324
# 2       1.70%       4.50%       8.40%      2.50%       5.40%      10.20%
# 3   4,779,736     710,231   6,392,017  2,915,918  37,253,956   5,029,196
# 4       6.00%       7.30%       6.30%      6.40%       6.30%       6.10%
# ..        ...         ...         ...        ...         ...         ...
# 60     41,943       7,953      46,780     25,915     252,377      51,722
# 61    316,984      56,091     427,582    192,988   3,176,341     469,524
# 62       94.4         1.2        56.3         56       239.1        48.5
# 63  50,645.33  570,640.95  113,594.08  52,035.48  155,779.22  103,641.89
# 64       "01"        "02"        "04"       "05"        "06"        "08"
#
#    Connecticut  Delaware     Florida     Georgia  ... South Dakota Tennessee  \
# 0    3,576,452   952,065  20,612,439  10,310,371  ...       865454   6651194
# 1    3,574,114   897,936  18,804,592   9,688,680  ...       814195   6346298
# 2        0.10%     6.00%       9.60%       6.40%  ...        0.063     0.048
# 3    3,574,097   897,934  18,801,310   9,687,653  ...       814180   6346105
# 4        5.20%     5.80%       5.50%       6.40%  ...        0.071     0.061
# ..         ...       ...         ...         ...  ...          ...       ...
# 60      31,056     7,206     185,756      96,787  ...         8604     59379
# 61     281,182    60,318   1,846,686     800,585  ...        66219    469392
# 62       738.1     460.8       350.6       168.4  ...         10.7     153.9
# 63    4,842.36  1,948.54   53,624.76   57,513.49  ...        75811   41234.9
# 64        "09"      "10"        "12"        "13"  ...         "46"      "47"
#
#          Texas       Utah   Vermont   Virginia Washington West Virginia  \
# 0   27,862,596  3,051,217   624,594  8,411,808  7,288,000     1,831,102
# 1   25,146,100  2,763,888   625,741  8,001,041  6,724,545     1,853,011
# 2       10.80%     10.40%    -0.20%      5.10%      8.40%        -1.20%
# 3   25,145,561  2,763,885   625,741  8,001,024  6,724,540     1,852,994
# 4        7.20%      8.30%     4.90%      6.10%      6.20%         5.50%
# ..         ...        ...       ...        ...        ...           ...
# 60     213,590     18,754     8,237     76,434     49,331        12,912
# 61   2,057,218    219,807    63,317    548,439    461,401        94,960
# 62        96.3       33.6      67.9      202.6      101.2          77.1
# 63  261,231.71  82,169.62  9,216.66  39,490.09  66,455.52     24,038.21
# 64        "48"       "49"      "50"       "51"       "53"          "54"
#
#     Wisconsin    Wyoming
# 0   5,778,708    585,501
# 1   5,687,289    563,767
# 2       1.60%      3.90%
# 3   5,686,986    563,626
# 4       5.80%      6.50%
# ..        ...        ...
# 60     39,830      6,470
# 61    370,755     51,353
# 62        105        5.8
# 63  54,157.80  97,093.14
# 64       "55"       "56"
#
# [65 rows x 50 columns]

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 52 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fact            80 non-null     object
#  1   Fact Note       28 non-null     object
#  2   Alabama         65 non-null     object
#  3   Alaska          65 non-null     object
#  4   Arizona         65 non-null     object
#  5   Arkansas        65 non-null     object
#  6   California      65 non-null     object
#  7   Colorado        65 non-null     object
#  8   Connecticut     65 non-null     object
#  9   Delaware        65 non-null     object
#  10  Florida         65 non-null     object
#  11  Georgia         65 non-null     object
#  12  Hawaii          65 non-null     object
#  13  Idaho           65 non-null     object
#  14  Illinois        65 non-null     object
#  15  Indiana         65 non-null     object
#  16  Iowa            65 non-null     object
#  17  Kansas          65 non-null     object
#  18  Kentucky        65 non-null     object
#  19  Louisiana       65 non-null     object
#  20  Maine           65 non-null     object
#  21  Maryland        65 non-null     object
#  22  Massachusetts   65 non-null     object
#  23  Michigan        65 non-null     object
#  24  Minnesota       65 non-null     object
#  25  Mississippi     65 non-null     object
#  26  Missouri        65 non-null     object
#  27  Montana         65 non-null     object
#  28  Nebraska        65 non-null     object
#  29  Nevada          65 non-null     object
#  30  New Hampshire   65 non-null     object
#  31  New Jersey      65 non-null     object
#  32  New Mexico      65 non-null     object
#  33  New York        65 non-null     object
#  34  North Carolina  65 non-null     object
#  35  North Dakota    65 non-null     object
#  36  Ohio            65 non-null     object
#  37  Oklahoma        65 non-null     object
#  38  Oregon          65 non-null     object
#  39  Pennsylvania    65 non-null     object
#  40  Rhode Island    65 non-null     object
#  41  South Carolina  65 non-null     object
#  42  South Dakota    65 non-null     object
#  43  Tennessee       65 non-null     object
#  44  Texas           65 non-null     object
#  45  Utah            65 non-null     object
#  46  Vermont         65 non-null     object
#  47  Virginia        65 non-null     object
#  48  Washington      65 non-null     object
#  49  West Virginia   65 non-null     object
#  50  Wisconsin       65 non-null     object
#  51  Wyoming         65 non-null     object
# dtypes: object(52)
# memory usage: 34.7+ KB

# %% [markdown]
# * Since the number of rows is 85, and the number of rows after dropping NaN values is 65, then all the 20 NaN values are from the same  columns.
# *Fact Note column seems to be useless with 57 NaN values, it should be dropped.
# * The Fact column has important information, more columns can be generated like the meaning of the values in the states' columns, date, and time.

# %% [markdown]
# ### Data Cleaning gun_df

# %%
gun_df = DropColumns(gun_df, 1000)
gun_df
# Out:
#          month          state   permit  handgun  long_gun  multiple  admin  \
# 0      2020-07        Alabama  48126.0  34909.0   17250.0      1170    0.0
# 1      2020-07         Alaska     69.0   4949.0    3779.0       283    0.0
# 2      2020-07        Arizona   9402.0  31040.0   12361.0      2866    0.0
# 3      2020-07       Arkansas   4292.0  12391.0    7322.0       432    3.0
# 4      2020-07     California  35097.0  67672.0   38618.0         0    0.0
# ...        ...            ...      ...      ...       ...       ...    ...
# 14350  1998-11       Virginia      0.0     14.0       2.0         8    0.0
# 14351  1998-11     Washington      1.0     65.0     286.0         8    1.0
# 14352  1998-11  West Virginia      3.0    149.0     251.0         5    0.0
# 14353  1998-11      Wisconsin      0.0     25.0     214.0         2    0.0
# 14354  1998-11        Wyoming      8.0     45.0      49.0         5    0.0
#
#        totals
# 0      107490
# 1       10108
# 2       60330
# 3       27647
# 4      149685
# ...       ...
# 14350      24
# 14351     361
# 14352     408
# 14353     241
# 14354     107
#
# [14355 rows x 8 columns]

# %% [markdown]
# Columns with very high number of missing values are dropped. The next step would be filling NaN values of the remaining columns.

# %%
gun_df.isna().sum()
# Out:
# month        0
# state        0
# permit      24
# handgun     20
# long_gun    19
# multiple     0
# admin       23
# totals       0
# dtype: int64

# %%
gun_df[gun_df.permit.isna()]
# Out:
#          month            state  permit  handgun  long_gun  multiple  admin  \
# 9149   2006-09        Louisiana     NaN   5948.0   10836.0       253    0.0
# 9180   2006-09         Virginia     NaN   6935.0   11023.0       242    0.0
# 9674   2005-12   Virgin Islands     NaN     22.0       1.0         0    NaN
# 9729   2005-11   Virgin Islands     NaN     13.0       2.0         1    NaN
# 9784   2005-10   Virgin Islands     NaN      NaN       NaN         0    NaN
# 9839   2005-09   Virgin Islands     NaN      NaN       NaN         0    NaN
# 9894   2005-08   Virgin Islands     NaN      NaN       NaN         0    NaN
# 9949   2005-07   Virgin Islands     NaN      NaN       NaN         0    NaN
# 10004  2005-06   Virgin Islands     NaN      NaN       NaN         0    NaN
# 10059  2005-05   Virgin Islands     NaN      NaN       NaN         0    NaN
# 10114  2005-04   Virgin Islands     NaN      NaN       1.0         0    NaN
# 10169  2005-03   Virgin Islands     NaN      NaN       NaN         0    NaN
# 10224  2005-02   Virgin Islands     NaN      NaN       NaN         0    NaN
# 10279  2005-01   Virgin Islands     NaN      NaN       NaN         0    NaN
# 10361  2004-11  Mariana Islands     NaN      NaN       NaN         0    NaN
# 11544  2003-02   Virgin Islands     NaN      NaN       NaN         0    NaN
# 13881  1999-07  Mariana Islands     NaN      NaN       NaN         0    NaN
# 13936  1999-06  Mariana Islands     NaN      NaN       NaN         0    NaN
# 13991  1999-05  Mariana Islands     NaN      NaN       NaN         0    NaN
# 14046  1999-04  Mariana Islands     NaN      NaN       NaN         0    0.0
# 14101  1999-03  Mariana Islands     NaN      NaN       NaN         0    NaN
# 14156  1999-02  Mariana Islands     NaN      NaN       NaN         0    NaN
# 14211  1999-01  Mariana Islands     NaN      NaN       NaN         0    NaN
# 14266  1998-12  Mariana Islands     NaN      NaN       NaN         0    NaN
#
#        totals
# 9149    19080
# 9180    18200
# 9674       23
# 9729       16
# 9784        0
# 9839        0
# 9894        0
# 9949        0
# 10004       0
# 10059       0
# 10114       1
# 10169       0
# 10224       0
# 10279       0
# 10361       0
# 11544       0
# 13881       0
# 13936       0
# 13991       0
# 14046       0
# 14101       0
# 14156       0
# 14211       0
# 14266       0

# %% [markdown]
# Most of the NaN values are from the same rows. They have totals of 0, they seem to be not very intuitive. They should be dropped as well.

# %%
gun_df.dropna(inplace=True)

# %% [markdown]
# 'month' column needs to be separated into years and months columns for more useful insights. A split will be occurred on '-' between the years and months values.

# %%
gun_df['year'] = gun_df.month.apply(lambda x: x.split('-')[0])
gun_df['month'] = gun_df.month.apply(lambda x: x.split('-')[1])
gun_df.head(2)
# Out:
#   month    state   permit  handgun  long_gun  multiple  admin  totals  year
# 0    07  Alabama  48126.0  34909.0   17250.0      1170    0.0  107490  2020
# 1    07   Alaska     69.0   4949.0    3779.0       283    0.0   10108  2020

# %% [markdown]
# The next step is just to make data appealing, year and month columns should be next to each other.

# %%
gun_df = BeginWithLast(gun_df)
gun_df.head(2)
# Out:
#    year month    state   permit  handgun  long_gun  multiple  admin  totals
# 0  2020    07  Alabama  48126.0  34909.0   17250.0      1170    0.0  107490
# 1  2020    07   Alaska     69.0   4949.0    3779.0       283    0.0   10108

# %% [markdown]
# ### Data Cleaning census_df

# %% [markdown]
# 'Fact Note' column has 57 NaN values out of 80, it should be dropped.

# %%
census_df.drop(columns='Fact Note', inplace=True)

# %% [markdown]
# Dropping NaN rows

# %%
census_df.dropna(inplace=True)

# %% [markdown]
# Most of Fact's rows have years values, some of them have just one value, and others have two values. The one value represents observations for each state at that year, while the two values represent growth through time frame in years.
# That's why the census_df will be split into 3 smaller dataframes.

# %%
census_0y_df = census_df[(census_df.Fact.apply(lambda x: getLengthYearValues(x))<1)]
census_0y_df
# Out:
#                                                  Fact Alabama  Alaska Arizona  \
# 37  Persons  without health insurance, under age 6...  10.70%  15.50%  11.90%
# 49                        Persons in poverty, percent  17.10%   9.90%  16.40%
# 64                                          FIPS Code    "01"    "02"    "04"
#
#    Arkansas California Colorado Connecticut Delaware Florida  ...  \
# 37    9.30%      8.30%    8.60%       5.70%    6.60%  15.30%  ...
# 49   17.20%     14.30%   11.00%       9.80%   11.70%  14.70%  ...
# 64     "05"       "06"     "08"        "09"     "10"    "12"  ...
#
#    South Dakota Tennessee   Texas    Utah Vermont Virginia Washington  \
# 37        0.103     0.106  18.60%   9.70%   4.50%   10.10%      6.90%
# 49        0.133     0.158  15.60%  10.20%  11.90%   11.00%     11.30%
# 64         "46"      "47"    "48"    "49"    "50"     "51"       "53"
#
#    West Virginia Wisconsin Wyoming
# 37         6.50%     6.20%  13.40%
# 49        17.90%    11.80%  11.30%
# 64          "54"      "55"    "56"
#
# [3 rows x 51 columns]

# %%
# 62         96.3        33.6        67.9        202.6        101.2
# 63   261,231.71   82,169.62    9,216.66    39,490.09    66,455.52
#
#    West Virginia    Wisconsin     Wyoming
# 0      1,831,102    5,778,708     585,501
# 3      1,852,994    5,686,986     563,626
# 4          5.50%        5.80%       6.50%
# 5          5.60%        6.30%       7.10%
# 6         20.50%       22.30%      23.70%
# 7         20.90%       23.60%      24.00%
# 8         18.80%       16.10%      15.00%
# 9         16.00%       13.70%      12.40%
# 10        50.50%       50.30%      48.90%
# 11        50.70%       50.40%      49.00%
# 12        93.60%       87.50%      92.80%
# 13         3.60%        6.60%       1.30%
# 14         0.20%        1.10%       2.70%
# 15         0.80%        2.80%       1.00%
# 16             Z        0.10%       0.10%
# 17         1.70%        1.90%       2.10%
# 18         1.50%        6.70%      10.00%
# 19        92.30%       81.70%      84.10%
# 22       886,640    2,668,444     270,600
# 23       881,917    2,624,358     261,868
# 29         2,544       19,274       1,727
# 40     4,036,333   10,303,256   1,644,844
# 41    12,259,395   40,680,625   3,291,478
# 42    24,553,072  177,728,926  10,783,794
# 43    14,295,437   77,066,883   5,597,891
# 44    22,637,923   78,201,822   9,446,043
# 45      $12,201      $13,656     $16,388
# 50        36,993      139,500      21,040
# 51       565,435    2,503,532     219,881
# 52    22,159,084  112,406,494  10,094,010
# 54        88,136      341,935      48,140
# 55       114,435      432,980      62,427
# 56        63,112      236,252      30,039
# 57        39,065      133,859      19,344
# 58         5,777       40,507       4,077
# 59       104,785      379,934      55,397
# 60        12,912       39,830       6,470
# 61        94,960      370,755      51,353
# 62          77.1          105         5.8
# 63     24,038.21    54,157.80   97,093.14
#
# [40 rows x 51 columns]

# %%
census_2y_df = census_df[(census_df.Fact.apply(lambda x: getLengthYearValues(x))==2)]
census_2y_df
# Out:
#                                                  Fact    Alabama     Alaska  \
# 1   Population estimates base, April 1, 2010,  (V2...  4,780,131    710,249
# 2   Population, percent change - April 1, 2010 (es...      1.70%      4.50%
# 20                                Veterans, 2011-2015    363,170     69,323
# 21           Foreign born persons, percent, 2011-2015      3.50%      7.40%
# 24        Owner-occupied housing unit rate, 2011-2015     68.70%     63.40%
# 25  Median value of owner-occupied housing units, ...  $125,500   $250,000
# 26  Median selected monthly owner costs -with a mo...    $1,139     $1,827
# 27  Median selected monthly owner costs -without a...      $345       $554
# 28                       Median gross rent, 2011-2015      $717     $1,146
# 30                              Households, 2011-2015  1,848,325    250,969
# 31                   Persons per household, 2011-2015       2.55       2.81
# 32  Living in same house 1 year ago, percent of pe...     85.30%     80.90%
# 33  Language other than English spoken at home, pe...      5.20%     16.20%
# 34  High school graduate or higher, percent of per...     84.30%     92.10%
# 35  Bachelor's degree or higher, percent of person...     23.50%     28.00%
# 36  With a disability, under age 65 years, percent...     11.80%      8.10%
# 38  In civilian labor force, total, percent of pop...     58.00%     67.70%
# 39  In civilian labor force, female, percent of po...     53.00%     65.00%
# 46  Mean travel time to work (minutes), workers ag...       24.4         19
# 47  Median household income (in 2015 dollars), 201...   $43,623    $72,515
# 48  Per capita income in past 12 months (in 2015 d...   $24,091    $33,413
#
#      Virginia Washington West Virginia  Wisconsin    Wyoming
# 1   8,001,041  6,724,545     1,853,011  5,687,289    563,767
# 2       5.10%      8.40%        -1.20%      1.60%      3.90%
# 20    706,539    564,864       150,021    381,940     48,505
# 21     11.70%     13.40%         1.50%      4.80%      3.60%
# 24     66.20%     62.50%        72.50%     67.30%     69.10%
# 25  $245,000   $259,500      $103,800   $165,800   $194,800
# 26    $1,711     $1,731          $966     $1,402     $1,348
# 27      $433       $511          $293       $532       $386
# 28    $1,116     $1,014          $643       $776       $789
# 30  3,062,783  2,668,912       740,890  2,299,107    226,865
# 31       2.62       2.56          2.43       2.43       2.49
# 32     84.40%     82.50%        88.20%     85.80%     81.90%
# 33     15.40%     18.90%         2.50%      8.70%      7.10%
# 34     88.30%     90.40%        85.00%     91.00%     92.30%
# 35     36.30%     32.90%        19.20%     27.80%     25.70%
# 36      7.70%      8.90%        14.40%      8.20%      8.50%
# 38     64.70%     63.50%        53.90%     67.10%     67.70%
# 39     60.80%     58.50%        49.20%     63.50%     62.70%
# 46       27.9       26.3          25.6       21.9       18.3
# 47   $65,015    $61,062       $41,751    $53,357    $58,840
# 48   $34,152    $31,762       $23,450    $28,340    $29,803
# 53      1.20%      2.90%        -1.70%      2.20%         FN
#
# [22 rows x 51 columns]

# %% [markdown]
# Fixing census_0y_df

# %%
float('17.10')
# Out:
# 17.1

# %%
census_0y_df.tail()
# Out:
#                                                  Fact Alabama  Alaska Arizona  \
# 37  Persons  without health insurance, under age 6...  10.70%  15.50%  11.90%
# 49                        Persons in poverty, percent  17.10%   9.90%  16.40%
# 64                                          FIPS Code    "01"    "02"    "04"
#
#    Arkansas California Colorado Connecticut Delaware Florida  ...  \
# 37    9.30%      8.30%    8.60%       5.70%    6.60%  15.30%  ...
# 49   17.20%     14.30%   11.00%       9.80%   11.70%  14.70%  ...
# 64     "05"       "06"     "08"        "09"     "10"    "12"  ...
#
#    South Dakota Tennessee   Texas    Utah Vermont Virginia Washington  \
# 37        0.103     0.106  18.60%   9.70%   4.50%   10.10%      6.90%
# 49        0.133     0.158  15.60%  10.20%  11.90%   11.00%     11.30%
# 64         "46"      "47"    "48"    "49"    "50"     "51"       "53"
#
#    West Virginia Wisconsin Wyoming
# 37         6.50%     6.20%  13.40%
# 49        17.90%    11.80%  11.30%
# 64          "54"      "55"    "56"
#
# [3 rows x 51 columns]

# %%
# removing commas and percent signs, and coverting them into float
census_0y_df[census_0y_df.columns[1:]] = census_0y_df[census_0y_df.columns[1:]]\
                                         .replace({',':'', '%':'', '"':''}, regex=True)\
                                         .replace('', np.nan)

states = census_0y_df.columns[1:]
for state in states:
    census_0y_df[state] = census_0y_df[state].astype(float)

census_0y_df.dtypes
# Out:
# Fact               object
# Alabama           float64
# Alaska            float64
# Arizona           float64
# Arkansas          float64
# California        float64
# Colorado          float64
# Connecticut       float64
# Delaware          float64
# Florida           float64
# Georgia           float64
# Hawaii            float64
# Idaho             float64
# Illinois          float64
# Indiana           float64
# Iowa              float64
# Kansas            float64
# Kentucky          float64
# Louisiana         float64
# Maine             float64
# Maryland          float64
# Massachusetts     float64
# Michigan          float64
# Minnesota         float64
# Mississippi       float64
# Missouri          float64
# Montana           float64
# Nebraska          float64
# Nevada            float64
# New Hampshire     float64
# New Jersey        float64
# New Mexico        float64
# New York          float64
# North Carolina    float64
# North Dakota      float64
# Ohio              float64
# Oklahoma          float64
# Oregon            float64
# Pennsylvania      float64
# Rhode Island      float64
# South Carolina    float64
# South Dakota      float64
# Tennessee         float64
# Texas             float64
# Utah              float64
# Vermont           float64
# Virginia          float64
# Washington        float64
# West Virginia     float64
# Wisconsin         float64
# Wyoming           float64
# dtype: object

# %% [markdown]
# Fixing census_1y_df

# %%
census_1y_df['Year'] = census_1y_df.Fact.apply(lambda x: re.findall(r'[0-9]{4}', x)[0])
census_1y_df.head(2)
# Out:
#                                            Fact    Alabama   Alaska  \
# 0  Population estimates, July 1, 2016,  (V2016)  4,863,300  741,894
# 3             Population, Census, April 1, 2010  4,779,736  710,231
#
#      Arizona   Arkansas  California   Colorado Connecticut Delaware  \
# 0  6,931,071  2,988,248  39,250,017  5,540,545   3,576,452  952,065
# 3  6,392,017  2,915,918  37,253,956  5,029,196   3,574,097  897,934
#
#       Florida  ... Tennessee       Texas       Utah  Vermont   Virginia  \
# 0  20,612,439  ...   6651194  27,862,596  3,051,217  624,594  8,411,808
# 3  18,801,310  ...   6346105  25,145,561  2,763,885  625,741  8,001,024
#
#   Washington West Virginia  Wisconsin  Wyoming  Year
# 0  7,288,000     1,831,102  5,778,708  585,501  2016
# 3  6,724,540     1,852,994  5,686,986  563,626  2010
#
# [2 rows x 52 columns]

# %%
# moving Year column to be in the start
census_1y_df = BeginWithLast(census_1y_df)
census_1y_df.head(2)
# Out:
#    Year                                          Fact    Alabama   Alaska  \
# 0  2016  Population estimates, July 1, 2016,  (V2016)  4,863,300  741,894
# 3  2010             Population, Census, April 1, 2010  4,779,736  710,231
#
#      Arizona   Arkansas  California   Colorado Connecticut Delaware  ...  \
# 0  6,931,071  2,988,248  39,250,017  5,540,545   3,576,452  952,065  ...
# 3  6,392,017  2,915,918  37,253,956  5,029,196   3,574,097  897,934  ...
#
#   South Dakota Tennessee       Texas       Utah  Vermont   Virginia  \
# 0       865454   6651194  27,862,596  3,051,217  624,594  8,411,808
# 3       814180   6346105  25,145,561  2,763,885  625,741  8,001,024
#
#   Washington West Virginia  Wisconsin  Wyoming
# 0  7,288,000     1,831,102  5,778,708  585,501
# 3  6,724,540     1,852,994  5,686,986  563,626
#
# [2 rows x 52 columns]

# %%
# having only the valuable information in Fact column
census_1y_df['Fact'] = census_1y_df.Fact.apply(lambda x: x.split(',')[0])
census_1y_df.head(2)
# Out:
#    Year                  Fact    Alabama   Alaska    Arizona   Arkansas  \
# 0  2016  Population estimates  4,863,300  741,894  6,931,071  2,988,248
# 3  2010            Population  4,779,736  710,231  6,392,017  2,915,918
#
#    California   Colorado Connecticut Delaware  ... South Dakota Tennessee  \
# 0  39,250,017  5,540,545   3,576,452  952,065  ...       865454   6651194
# 3  37,253,956  5,029,196   3,574,097  897,934  ...       814180   6346105
#
#         Texas       Utah  Vermont   Virginia Washington West Virginia  \
# 0  27,862,596  3,051,217  624,594  8,411,808  7,288,000     1,831,102
# 3  25,145,561  2,763,885  625,741  8,001,024  6,724,540     1,852,994
#
#    Wisconsin  Wyoming
# 0  5,778,708  585,501
# 3  5,686,986  563,626
#
# [2 rows x 52 columns]

# %%
# removing commas and percent signs, and coverting them into float
census_1y_df[census_1y_df.columns[2:]] = census_1y_df[census_1y_df.columns[2:]]\
                                         .replace({',':'', '%':'', '\$':'', '[a-zA-Z]':''}, regex=True)\
                                         .replace({'':np.nan})

states = census_1y_df.columns[2:]

for state in states:
    census_1y_df[state] = census_1y_df[state].astype(float)

census_1y_df.dtypes
# Out:
# Year               object
# Fact               object
# Alabama           float64
# Alaska            float64
# Arizona           float64
# Arkansas          float64
# California        float64
# Colorado          float64
# Connecticut       float64
# Delaware          float64
# Florida           float64
# Georgia           float64
# Hawaii            float64
# Idaho             float64
# Illinois          float64
# Indiana           float64
# Iowa              float64
# Kansas            float64
# Kentucky          float64
# Louisiana         float64
# Maine             float64
# Maryland          float64
# Massachusetts     float64
# Michigan          float64
# Minnesota         float64
# Mississippi       float64
# Missouri          float64
# Montana           float64
# Nebraska          float64
# Nevada            float64
# New Hampshire     float64
# New Jersey        float64
# New Mexico        float64
# New York          float64
# North Carolina    float64
# North Dakota      float64
# Ohio              float64
# Oklahoma          float64
# Oregon            float64
# Pennsylvania      float64
# Rhode Island      float64
# South Carolina    float64
# South Dakota      float64
# Tennessee         float64
# Texas             float64
# Utah              float64
# Vermont           float64
# Virginia          float64
# Washington        float64
# West Virginia     float64
# Wisconsin         float64
# Wyoming           float64
# dtype: object

# %% [markdown]
# Fixing census_2y_df

# %%
# having starting and ending years to the corresponding values
census_2y_df['StartYear'] = census_2y_df.Fact.apply(lambda x: re.findall(r'[0-9]{4}', x)[0])
census_2y_df['EndYear'] = census_2y_df.Fact.apply(lambda x: re.findall(r'[0-9]{4}', x)[1])

census_2y_df = BeginWithLast(census_2y_df)
census_2y_df = BeginWithLast(census_2y_df)

census_2y_df.head(2)
# Out:
#   StartYear EndYear                                               Fact  \
# 1      2010    2016  Population estimates base, April 1, 2010,  (V2...
# 2      2010    2016  Population, percent change - April 1, 2010 (es...
#
#      Alabama   Alaska    Arizona   Arkansas  California   Colorado  \
# 1  4,780,131  710,249  6,392,301  2,916,025  37,254,522  5,029,324
# 2      1.70%    4.50%      8.40%      2.50%       5.40%     10.20%
#
#   Connecticut  ... South Dakota Tennessee       Texas       Utah  Vermont  \
# 1   3,574,114  ...       814195   6346298  25,146,100  2,763,888  625,741
# 2       0.10%  ...        0.063     0.048      10.80%     10.40%   -0.20%
#
#     Virginia Washington West Virginia  Wisconsin  Wyoming
# 1  8,001,041  6,724,545     1,853,011  5,687,289  563,767
# 2      5.10%      8.40%        -1.20%      1.60%    3.90%
#
# [2 rows x 53 columns]

# %%
# having only the valuable information in Fact column
census_2y_df['Fact'] = census_2y_df.Fact.apply(lambda x: x.split(',')[0])
census_2y_df.head(2)
# Out:
#   StartYear EndYear                       Fact    Alabama   Alaska    Arizona  \
# 1      2010    2016  Population estimates base  4,780,131  710,249  6,392,301
# 2      2010    2016                 Population      1.70%    4.50%      8.40%
#
#     Arkansas  California   Colorado Connecticut  ... South Dakota Tennessee  \
# 1  2,916,025  37,254,522  5,029,324   3,574,114  ...       814195   6346298
# 2      2.50%       5.40%     10.20%       0.10%  ...        0.063     0.048
#
#         Texas       Utah  Vermont   Virginia Washington West Virginia  \
# 1  25,146,100  2,763,888  625,741  8,001,041  6,724,545     1,853,011
# 2      10.80%     10.40%   -0.20%      5.10%      8.40%        -1.20%
#
#    Wisconsin  Wyoming
# 1  5,687,289  563,767
# 2      1.60%    3.90%
#
# [2 rows x 53 columns]

# %%
# removing commas and percent signs, and coverting them into float
census_2y_df[census_2y_df.columns[3:]] = census_2y_df[census_2y_df.columns[3:]]\
                                         .replace({',':'', '%':'', '\$':'', '\D':''}, regex=True)\
                                         .replace({'':np.nan})

states = census_2y_df.columns[3:]

for state in states:
    census_2y_df[state] = census_2y_df[state].astype(float)

census_2y_df.dtypes
# Out:
# StartYear          object
# EndYear            object
# Fact               object
# Alabama           float64
# Alaska            float64
# Arizona           float64
# Arkansas          float64
# California        float64
# Colorado          float64
# Connecticut       float64
# Delaware          float64
# Florida           float64
# Georgia           float64
# Hawaii            float64
# Idaho             float64
# Illinois          float64
# Indiana           float64
# Iowa              float64
# Kansas            float64
# Kentucky          float64
# Louisiana         float64
# Maine             float64
# Maryland          float64
# Massachusetts     float64
# Michigan          float64
# Minnesota         float64
# Mississippi       float64
# Missouri          float64
# Montana           float64
# Nebraska          float64
# Nevada            float64
# New Hampshire     float64
# New Jersey        float64
# New Mexico        float64
# New York          float64
# North Carolina    float64
# North Dakota      float64
# Ohio              float64
# Oklahoma          float64
# Oregon            float64
# Pennsylvania      float64
# Rhode Island      float64
# South Carolina    float64
# South Dakota      float64
# Tennessee         float64
# Texas             float64
# Utah              float64
# Vermont           float64
# Virginia          float64
# Washington        float64
# West Virginia     float64
# Wisconsin         float64
# Wyoming           float64
# dtype: object

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %%
# row with index 0 is the row for population estimates
((census_1y_df[census_1y_df.columns[2:]].loc[0])/1000000).sort_values(ascending=True)\
.plot(x=states, kind='barh', figsize=(12, 10), stacked=True);
plt.xlabel('Population in Millions', fontsize=12)
plt.ylabel('States', fontsize=12)
plt.title('Population Estimates 2016', fontsize=15)
plt.show()

# %% [markdown]
# From the horizontal bar chart, we can conclude that based on the Population Estimates in 2016 that California has the largest population of around 40 millions people, Texas comes second in place, and so on, to a point that some states have less than 1 million people like Wyoming, Vermont, and Alaska.

# %%
# row with index 48 is the row for per capita income for a year
((census_2y_df[census_2y_df.columns[3:]].loc[48])/1000).sort_values(ascending=True)\
.plot(kind='barh', figsize=(12, 10));
plt.xlabel('Thousands US Dollars', fontsize=12)
plt.ylabel('States', fontsize=12)
plt.title('Per Capita Yearly Income 2015', fontsize=15)
plt.show()

# %% [markdown]
# There is around US$15,000 difference between the highest state and lowest state in yearly income. Having that number alone is not enough to give a judgment on how things are in the states, but as an indication, it works fine.

# %%
# row with index 49 is the row for percentage of poverty
(census_0y_df[census_0y_df.columns[1:]].loc[49]).sort_values(ascending=True)\
.plot(kind='barh', figsize=(12, 10));
plt.xlabel('Percentage', fontsize=12)
plt.ylabel('States', fontsize=12)
plt.title('Poverty', fontsize=15)
plt.show()

# %% [markdown]
# There is a huge difference between states in terms of poverty percentage.

# %% [markdown]
# ### Research Question 1: Which states perform the highest number of background checks?

# %%
(gun_df[gun_df.year=='2015'].groupby('state').totals.sum()/10**3)\
.sort_values(ascending=True).plot(kind='barh', figsize=(12, 10));
plt.ylabel('State', fontsize=12)
plt.xlabel('thousands Background Checks', fontsize=12)
plt.title('Background Checks by States 2015', fontsize=15)
plt.show()

# %% [markdown]
# Kentucky, California, and Texas perform the highest number of background checks. This number alone does not represent how restrict they are, because the number of admitting customers are allowed to purchase the firearm is not available.

# %% [markdown]
# ### Research Question 2: Which states have had the highest growth in gun registrations?

# %%
states = list(gun_df.state.unique())

plt.figure(figsize=(15, 12))
for state in states:
    gun_df[gun_df.state==state].groupby('year').totals.sum().plot(kind='line', label=state);

plt.xlabel('Year', fontsize=15)
plt.ylabel('Background Checks', fontsize=15)
plt.title('Registerations in States', fontsize=20)
plt.legend(bbox_to_anchor=(1.2, 1.15))
plt.show()

# %% [markdown]
# Get the mean of sum of totals in for each state, and specify which have the highest values and plot only the highest 10 percent of means.

# %%
from collections import Counter

mean_of_totals_dict = {}
for state in states:
    mean_of_totals_dict.update({state:gun_df[gun_df.state==state].groupby('year').totals.sum().mean()})
    
k = Counter(mean_of_totals_dict)

highest_5_states = k.most_common(5)
print('State: Number of Background Checks -mean-')

for i in highest_5_states: 
    print(i[0]," :",i[1]," ")
# Out:
# State: Number of Background Checks -mean-
# Kentucky  : 1839493.5217391304
# Illinois  : 1229658.347826087
# Texas  : 1057936.6956521738
# California  : 993598.2173913043
# Pennsylvania  : 704697.6086956522

# %%
highest_states = [i[0] for i in highest_5_states]

plt.figure(figsize=(10, 8))
for state in highest_states:
    gun_df[gun_df.state==state].groupby('year').totals.sum().plot(kind='line', label=state);

plt.xlabel('Year', fontsize=12)
plt.ylabel('Background Checks', fontsize=12)
plt.title('Registerations in States', fontsize=15)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Kentucky and Illinois seem to be the highest increase in background checks, although the trend shows that Kentucky has drastically decreased lately for some reason.

# %% [markdown]
# ### Research Question 3: What is the overall trend of gun purchases?

# %%
(gun_df.groupby('year').totals.sum()/(10**6)).plot(kind='line', figsize=(8, 6));
plt.xlabel('Year', fontsize=12)
plt.ylabel('Millions Background Checks', fontsize=12)
plt.title('Gun Purchases', fontsize=15)
plt.show()

# %% [markdown]
# Since Background Checks is a directly proportional factor with gun purchases, and Background Checks is increasing through the time, then the trend of gun purchases is generally increasing.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# One of the limitations of my explorations (other research questions I wanted look for) is the absence of whether the background check resulted in allowing the customer to purchase or rent the firearm.
# With the available data, I reached accepted answers to the questions of
# * Which states have performed the highest number of background checks?
# This is represented in the horizontal bar chart, and it is easily detected that of year 2015, Kentucky had the highest number of background checks.
# * Which states are having the highest growth in gun registrations?
# This question was answered with one line plot that contained all the 50 states, but it was not convenient to get exactly which state has the highest growth because the colors were so close, so instead of that, only the highest 5 means of the sum of the totals of each state were representative of which states should be focused on, and the graph was clear to draw conclusions from.
# * What is the overall gun purchases trend in the US?
# Line plot of the sum of totals of all the dataset is representative and intuitive. It is increasing over the time. If the data of population of US is available across the same time of the gun purchases, the two plots would have been more descriptive of answering a question that I have in mind which is *Are the people more or less into purchasing firearms?*

# %% [markdown]
# Github Repo's README file used to fully understand what columns mean --> https://github.com/BuzzFeedNews/nics-firearm-background-checks/blob/master/README.md
